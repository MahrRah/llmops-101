# %%
# !pip install langchain
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (0.3.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (0.3.13)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: anyio in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Collecting langchain-openai
#   Downloading langchain_openai-0.2.3-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-openai) (0.3.13)
# Requirement already satisfied: openai<2.0.0,>=1.52.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-openai) (1.52.2)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (0.1.137)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (0.6.1)
# Requirement already satisfied: sniffio in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (4.66.6)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Downloading regex-2024.9.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.52.0->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.12->langchain-openai) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.12->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.12->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.12->langchain-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mahrarahimi/Workspace/Code/CodeSample/llmops-101/.venv/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.3)
# Downloading langchain_openai-0.2.3-py3-none-any.whl (49 kB)
# Downloading tiktoken-0.8.0-cp311-cp311-macosx_11_0_arm64.whl (982 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 982.4/982.4 kB 1.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading regex-2024.9.11-cp311-cp311-macosx_11_0_arm64.whl (284 kB)
# Installing collected packages: regex, tiktoken, langchain-openai
# Successfully installed langchain-openai-0.2.3 regex-2024.9.11 tiktoken-0.8.0

# %%
# %load_ext dotenv
# %dotenv ../.env

# %%
import os

from langchain_openai import AzureChatOpenAI

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

llm = AzureChatOpenAI(
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    api_version="2024-02-01",
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant."),
        ("user", "Does Azure OpenAI support customer managed keys?"),
        ("assistant", "Yes, customer managed keys are supported by Azure OpenAI."),
        ("user", "{input}"),
    ]
)

output_parser = StrOutputParser()

chain = prompt | llm | output_parser
response = chain.invoke({"input": "Do other Azure AI services support this too?"})
print(response)
# Out:
# Yes, many other Azure AI services also support the use of customer-managed keys (CMKs) for encryption. This allows customers to have control over the encryption keys and the responsibility for managing and maintaining the keys. Azure services like Azure Cognitive Services allow the use of customer-managed keys to help meet specific compliance requirements and enhance the security of your data.
#
# It's important to check the specific documentation of each Azure AI service to understand the details of how they implement CMK support, as the implementation and capabilities may vary between services.
